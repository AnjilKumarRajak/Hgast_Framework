# %% [markdown]
# # 🎙️ HGAST Framework - Google Colab Live Launcher
# ### Hierarchical Gender Arbitration for Speech Translation
#
# Run this notebook on Google Colab (Free T4 GPU / CPU) to launch your live HGAST Framework Gradio app with a public URL!

# %%
# Step 1: Clone Repository & Install Dependencies
# !git clone https://github.com/AnjilKumarRajak/Hgast_Framework.git
# %cd Hgast_Framework
# !pip install gradio huggingface_hub edge-tts requests fastapi uvicorn librosa soundfile spacy gender-guesser -q

# %%
# Step 2: Launch Live HGAST Framework with Public Share Link
import sys, os
sys.path.insert(0, os.path.abspath("backend"))

from app import demo
demo.launch(share=True)
